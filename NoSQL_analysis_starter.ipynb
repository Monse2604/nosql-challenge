# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Assign the collection to a variable
establishments = db['establishments']

# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Number of establishments with a hygiene score of 20: {count}")

# Display the first document in the results using pprint
from pprint import pprint
result = establishments.find_one(query)
pprint(result)
# Out:
# Number of establishments with a hygiene score of 20: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('677b1ecc484c06fc3faa7911'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
#  'latitude': None,
# ...

# %%
# Convert the result to a Pandas DataFrame
results = list(establishments.find(query))
df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(f"Number of rows in the DataFrame: {len(df)}")

# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  677b1ecc484c06fc3faa7911   110681                  0
# 1  677b1ecc484c06fc3faa7ca2   612039                  0
# 2  677b1ecc484c06fc3faa7f9b   730933                  0
# 3  677b1ecc484c06fc3faa8189   172735                  0
# 4  677b1ecc484c06fc3faa8199   172953                  0
# 5  677b1ecc484c06fc3faa8b35   512854                  0
# 6  677b1ecc484c06fc3faa8d59  1537089                  0
# 7  677b1ecd484c06fc3faaa284   155648                  0
# 8  677b1ecd484c06fc3faaa6d4  1012883                  0
# 9  677b1ecd484c06fc3faaaed8   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName": {"$regex": "London", "$options": "i"}}
count = establishments.count_documents(query)
print(f"Number of establishments with LocalAuthorityName containing 'London': {count}")


# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Number of establishments in London with a RatingValue >= 4: {count}")

# Display the first document in the results using pprint
from pprint import pprint
result = establishments.find_one(query)
pprint(result)
# Out:
# Number of establishments with LocalAuthorityName containing 'London': 37
# Number of establishments in London with a RatingValue >= 4: 37
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
# ...

# %%
# Convert the result to a Pandas DataFrame
import pandas as pd
results = list(establishments.find(query))
df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(f"Number of rows in DataFrame: {len(df)}")

# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# Number of rows in DataFrame: 37
#                         _id   FHRSID  ChangesByServerID  \
# 0  677b1ecd484c06fc3faa932b   621707                  0
# 1  677b1ecd484c06fc3faa9652  1130836                  0
# 2  677b1ecd484c06fc3faaa19d   293783                  0
# 3  677b1ecd484c06fc3faaa7bd  1523645                  0
# 4  677b1ecd484c06fc3faaaf9d  1315095                  0
# 5  677b1ecd484c06fc3faaafa1   294474                  0
# 6  677b1ecd484c06fc3faab6a8   294900                  0
# 7  677b1ecd484c06fc3faad7b1  1252616                  0
# 8  677b1ecd484c06fc3faad7b6   293756                  0
# 9  677b1ecd484c06fc3faadb7c   878523                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
from pprint import pprint
# Search within 0.01 degree on either side of the latitude and longitude
degree_search = 0.01

# Latitude and longitude of "Penang Flavours"
establishments.update_one(
    {"BusinessName": "Penang Flavours"},
    {
        "$set": {
            "geocode.latitude": 51.490142,
            "geocode.longitude": 0.100623,
            "RatingValue": 5
        }
    }
)

# Define the query
query = {
    "RatingValue": rating_value,
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
}


# Define sorting by Hygiene score (ascending)
sort = [("scores.Hygiene", 1)]  # 1 for ascending, -1 for descending

# Limit the result to top 5
limit = 5

# Fetch the results
results = list(establishments.find(query).sort(sort).limit(limit))

# Print the results
print("Top 5 establishments with RatingValue = 5 sorted by Hygiene score:")
pprint(results)
# Out:
# Top 5 establishments with RatingValue = 5 sorted by Hygiene score:
# [{'AddressLine1': 'Greenwich',
#   'AddressLine2': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': '',
#   'BusinessTypeID': 1,
#   'PostCode': '',
#   'RatingValue': 5,
#   '_id': ObjectId('677b217e731046826a3d254a'),
#   'geocode': {'latitude': 51.490142, 'longitude': 0.100623},
#   'latitude': None,
#   'longitude': None,
#   'scores': None}]

# %%
# Convert result to Pandas DataFrame
import pandas as pd

# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(f"Number of rows in DataFrame: {len(df)}")

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(df.head(10))
# Out:
# Number of rows in DataFrame: 1
# First 10 rows of the DataFrame:
#                         _id     BusinessName BusinessType  RatingValue  \
# 0  677b217e731046826a3d254a  Penang Flavours                         5
#
#   AddressLine1 AddressLine2 PostCode longitude latitude scores  \
# 0    Greenwich                            None     None   None
#
#    BusinessTypeID                                         geocode
# 0               1  {'latitude': 51.490142, 'longitude': 0.100623}

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
pipeline = [
    {"$match": {"scores.Hygiene": 0}},  # 1. Matches establishments with a hygiene score of 0
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},  # 2. Groups by Local Authority
    {"$sort": {"count": -1}}  # 3. Sorts the matches from highest to lowest
]

# Execute the pipeline
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f"Number of Local Authorities with establishments with a hygiene score of 0: {len(results)}")

# Print the first 10 results
print("Top 10 Local Authorities with the most establishments with a hygiene score of 0:")
from pprint import pprint
pprint(results[:10])
# Out:
# Number of Local Authorities with establishments with a hygiene score of 0: 55
# Top 10 Local Authorities with the most establishments with a hygiene score of 0:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
import pandas as pd

# Convert the results to a DataFrame
df = pd.DataFrame(results)

# Rename the columns for better readability
df.rename(columns={"_id": "LocalAuthorityName", "count": "EstablishmentCount"}, inplace=True)

# Display the number of rows in the DataFrame
print(f"Number of rows in the DataFrame: {len(df)}")

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 55
# First 10 rows of the DataFrame:
#   LocalAuthorityName  EstablishmentCount
# 0             Thanet                1130
# 1          Greenwich                 882
# 2          Maidstone                 713
# 3             Newham                 711
# 4              Swale                 686
# 5         Chelmsford                 680
# 6             Medway                 672
# 7             Bexley                 607
# 8    Southend-On-Sea                 586
# 9           Tendring                 542
